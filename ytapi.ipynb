# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
from pprint import pprint
import json
import re
import urllib.request
import pprint
import time

# Import API key
from config import ytkey

# YouTube data file path
file = os.path.join("data/USvideos.csv")

# File path for API Call results
output_data_file = os.path.join("data/ChannelID.csv")

# %%
#Read in csv from kaggle
ytdata = pd.read_csv(file)
ytdata.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
videos = ytdata["video_id"]
videos_df = pd.DataFrame(videos)
videos_df
# Out:
#           video_id
# 0      2kyS6SvSYSE
# 1      1ZAPwfrtAFY
# 2      5qpjK5DgCt4
# 3      puqaWrEC7tY
# 4      d380meD0W0M
# ...            ...
# 40944  BZt0qjTWNhw
# 40945  1h7KV2sjUWY
# 40946  D6Oy4LfoqsU
# 40947  oV0zkMe1K8s
# 40948  ooyjaVdt-jA
#
# [40949 rows x 1 columns]

# %%
videos_df_unique = videos_df.drop_duplicates()
videos_df_unique.reset_index(inplace=True)
videos_df_unique = videos_df_unique.drop(['index'], axis=1)
# videos_df_unique.set_index("index", inplace=True)
videos_df_unique
# Out:
#          video_id
# 0     2kyS6SvSYSE
# 1     1ZAPwfrtAFY
# 2     5qpjK5DgCt4
# 3     puqaWrEC7tY
# 4     d380meD0W0M
# ...           ...
# 6346  dS5Thrl-4Kc
# 6347  JGm9Y_hFqNk
# 6348  6h8QgZF5Qu4
# 6349  mpnshdmtE2Y
# 6350  yz7Xq3T0YPs
#
# [6351 rows x 1 columns]

# %%
videos = videos_df_unique["video_id"]
print(videos)
# Out:
# 0       2kyS6SvSYSE
# 1       1ZAPwfrtAFY
# 2       5qpjK5DgCt4
# 3       puqaWrEC7tY
# 4       d380meD0W0M
#            ...
# 6346    dS5Thrl-4Kc
# 6347    JGm9Y_hFqNk
# 6348    6h8QgZF5Qu4
# 6349    mpnshdmtE2Y
# 6350    yz7Xq3T0YPs
# Name: video_id, Length: 6351, dtype: object

# %%
key = ytkey
service = "youtube"
version = "v3"
type = "videos"
part = "snippet"

# %%
url = f"https://www.googleapis.com/{service}/{version}/{type}?part={part}&key={ytkey}&id=2kyS6SvSYSE"
response = requests.get(url).json()
response
# Out:
# {'error': {'errors': [{'domain': 'usageLimits',
#     'reason': 'dailyLimitExceeded',
#     'message': 'Daily Limit Exceeded. The quota will be reset at midnight Pacific Time (PT). You may monitor your quota usage and adjust limits in the API Console: https://console.developers.google.com/apis/api/youtube.googleapis.com/quotas?project=1085230254895',
#     'extendedHelp': 'https://console.developers.google.com/apis/api/youtube.googleapis.com/quotas?project=1085230254895'}],
#   'code': 403,
#   'message': 'Daily Limit Exceeded. The quota will be reset at midnight Pacific Time (PT). You may monitor your quota usage and adjust limits in the API Console: https://console.developers.google.com/apis/api/youtube.googleapis.com/quotas?project=1085230254895'}}

# %%
url = f"https://www.googleapis.com/{service}/{version}/{type}?part={part}&key={ytkey}&id="
video_id = []
channel_id = []
results = []

for video in videos:
    response = requests.get(url + video).json()
    try:
        channel_id.append(response["items"][0]["snippet"]["channelId"])
        results.append(print(f"Search for {video} found. Results added to library."))
    except (KeyError, IndexError):
        results.append(print(f"Search for {video} not found. Skipping."))
    time.sleep(1)
# Out:
# Search for 2kyS6SvSYSE found. Results added to library.
# Search for 1ZAPwfrtAFY found. Results added to library.
# Search for 5qpjK5DgCt4 found. Results added to library.
# Search for puqaWrEC7tY found. Results added to library.
# Search for d380meD0W0M found. Results added to library.
# Search for gHZ1Qz0KiKM found. Results added to library.
# Search for 39idVpFF7NQ found. Results added to library.
# Search for nc99ccSXST0 found. Results added to library.
# Search for jr9QtXwC9vc found. Results added to library.
# Search for TUmyygCMMGA found. Results added to library.
# Search for 9wRQljFNDW8 found. Results added to library.
# Search for VifQlJit6A0 found. Results added to library.
# Search for 5E4ZBSInqUU found. Results added to library.
# Search for GgVmn66oK_A found. Results added to library.
# Search for TaTleo4cOs8 found. Results added to library.
# Search for kgaO45SyaO4 found. Results added to library.
# Search for ZAQs-ctOqXQ found. Results added to library.
# ...

# %%
weather_df.to_csv(output_data_file, mode = "w", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-956bf59d6fc9> in <module>
# ----> 1 channel_id
#
# NameError: name 'channel_id' is not defined

# %%
key = ytkey
service = "youtube"
version = "v3"
type = "channels"
part = "statistics"

# %%
url = f"https://www.googleapis.com/{service}/{version}/{type}?part={part}&key={ytkey}&id="
channel_id = []
results = []

for video in videos:
    response = requests.get(url + video).json()
    try:
        channel_id.append(response["items"][0]["snippet"]["channelId"])
        results.append(print(f"Search for {video} found. Results added to library."))
    except (KeyError, IndexError):
        results.append(print(f"Search for {video} not found. Skipping."))
    time.sleep(1)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '"SJZWTG6xR0eGuCOh2bX6w3s4F94/FmpOoE1bG5jT8YVNHqe314Pojyk"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"SJZWTG6xR0eGuCOh2bX6w3s4F94/pX52Pm7ByeVxG3ozWuUqOADRUjA"',
#    'id': 'UC3XTzVzaHQEd30rQbuvCtTQ',
#    'statistics': {'viewCount': '2339879838',
#     'commentCount': '0',
#     'subscriberCount': '7630000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '299'}}]}

# %%
data["items"][0]["statistics"]["videoCount"]
# Out:
# '299'
